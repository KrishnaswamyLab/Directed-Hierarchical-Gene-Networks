# %%
from sklearn.model_selection import train_test_split
from scipy.spatial.distance import pdist, squareform, cdist
import numpy as np
import scipy, torch, phate, scprep
import torch_geometric.transforms as T
from sklearn import linear_model, metrics
import networkx as nx
import pandas as pd
from torch_geometric.data import Data
import os
from collections import defaultdict, Counter
import matplotlib.pyplot as plt
import scprep
from scipy.stats import spearmanr

# %%
np.random.seed(1234)
torch.manual_seed(1234)

interactions = pd.read_csv('../data/omnipath_curated_interactions.csv', index_col=0)

# %%
G = nx.from_pandas_edgelist(interactions, source='source_genesymbol', target='target_genesymbol', create_using=nx.DiGraph)
coo = scipy.sparse.coo_matrix(scipy.sparse.coo_matrix(nx.adjacency_matrix(G)))
values = coo.data
indices = np.vstack((coo.row, coo.col))

i = torch.LongTensor(indices)
v = torch.FloatTensor(values)
shape = coo.shape

# %%
data = Data(x=torch.Tensor(np.eye(G.number_of_nodes())), 
            edge_index=torch.sparse_coo_tensor(i, v, torch.Size(shape)).to_dense().nonzero().t().contiguous())

# %%
embedding_files = [x for x in os.listdir('results/MagNet') if x.endswith('existence_omnipath_embedding.npy')]
embeddings = dict(zip([x.split('_embedding.npy')[0] for x in embedding_files], [np.load(f'results/MagNet/{x}') for x in embedding_files]))

# %%
for k,v in embeddings.items():
    print (k, v.shape)
# Out:
# 262_existence_omnipath (8909, 16)
# 194_existence_omnipath (8909, 16)
# 104_existence_omnipath (8909, 16)
# 4_existence_omnipath (8909, 16)
# 59_existence_omnipath (8909, 16)
# 82_existence_omnipath (8909, 16)
# 108_existence_omnipath (8909, 16)
# 270_existence_omnipath (8909, 16)
# 13_existence_omnipath (8909, 16)
# 267_existence_omnipath (8909, 16)
# 284_existence_omnipath (8909, 16)
# 276_existence_omnipath (8909, 16)
# 277_existence_omnipath (8909, 16)
# 272_existence_omnipath (8909, 16)
# 220_existence_omnipath (8909, 16)
# 282_existence_omnipath (8909, 16)
# 144_existence_omnipath (8909, 16)
# 105_existence_omnipath (8909, 16)
# 88_existence_omnipath (8909, 16)
# 223_existence_omnipath (8909, 16)
# 187_existence_omnipath (8909, 16)
# 252_existence_omnipath (8909, 16)
# 265_existence_omnipath (8909, 16)
# 230_existence_omnipath (8909, 16)
# 121_existence_omnipath (8909, 16)
# 16_existence_omnipath (8909, 16)
# 53_existence_omnipath (8909, 16)
# 213_existence_omnipath (8909, 16)
# 162_existence_omnipath (8909, 16)
# 227_existence_omnipath (8909, 16)
# 94_existence_omnipath (8909, 16)
# 10_existence_omnipath (8909, 16)
# 283_existence_omnipath (8909, 16)
# 205_existence_omnipath (8909, 16)
# 136_existence_omnipath (8909, 16)
# 181_existence_omnipath (8909, 16)
# 17_existence_omnipath (8909, 16)
# 33_existence_omnipath (8909, 16)
# 7_existence_omnipath (8909, 16)
# 171_existence_omnipath (8909, 16)
# 115_existence_omnipath (8909, 16)
# 43_existence_omnipath (8909, 16)
# 211_existence_omnipath (8909, 16)
# 76_existence_omnipath (8909, 16)
# 226_existence_omnipath (8909, 16)
# 196_existence_omnipath (8909, 16)
# 229_existence_omnipath (8909, 16)
# 21_existence_omnipath (8909, 16)
# 140_existence_omnipath (8909, 16)
# 141_existence_omnipath (8909, 16)
# 193_existence_omnipath (8909, 16)
# 110_existence_omnipath (8909, 16)
# 89_existence_omnipath (8909, 16)
# 216_existence_omnipath (8909, 16)
# 80_existence_omnipath (8909, 16)
# 35_existence_omnipath (8909, 16)
# 208_existence_omnipath (8909, 16)
# 39_existence_omnipath (8909, 16)
# 9_existence_omnipath (8909, 16)
# 66_existence_omnipath (8909, 16)
# 266_existence_omnipath (8909, 16)
# 204_existence_omnipath (8909, 16)
# 132_existence_omnipath (8909, 16)
# 23_existence_omnipath (8909, 16)
# 129_existence_omnipath (8909, 16)
# 238_existence_omnipath (8909, 16)
# 179_existence_omnipath (8909, 16)
# 219_existence_omnipath (8909, 16)
# 72_existence_omnipath (8909, 16)
# 68_existence_omnipath (8909, 16)
# 116_existence_omnipath (8909, 16)
# 180_existence_omnipath (8909, 16)
# 224_existence_omnipath (8909, 16)
# 232_existence_omnipath (8909, 16)
# 234_existence_omnipath (8909, 16)
# 48_existence_omnipath (8909, 16)
# 65_existence_omnipath (8909, 16)
# 100_existence_omnipath (8909, 16)
# 20_existence_omnipath (8909, 16)
# 71_existence_omnipath (8909, 16)
# 150_existence_omnipath (8909, 16)
# 57_existence_omnipath (8909, 16)
# 84_existence_omnipath (8909, 16)
# 86_existence_omnipath (8909, 16)
# 247_existence_omnipath (8909, 16)
# 160_existence_omnipath (8909, 16)
# 258_existence_omnipath (8909, 16)
# 269_existence_omnipath (8909, 16)
# 11_existence_omnipath (8909, 16)
# 19_existence_omnipath (8909, 16)
# 64_existence_omnipath (8909, 16)
# 271_existence_omnipath (8909, 16)
# 2_existence_omnipath (8909, 16)
# 274_existence_omnipath (8909, 16)
# 46_existence_omnipath (8909, 16)
# 147_existence_omnipath (8909, 16)
# 214_existence_omnipath (8909, 16)
# 50_existence_omnipath (8909, 16)
# 29_existence_omnipath (8909, 16)
# 3_existence_omnipath (8909, 16)
# 250_existence_omnipath (8909, 16)
# 127_existence_omnipath (8909, 16)
# 207_existence_omnipath (8909, 16)
# 285_existence_omnipath (8909, 16)
# 243_existence_omnipath (8909, 16)
# 287_existence_omnipath (8909, 16)
# 93_existence_omnipath (8909, 16)
# 90_existence_omnipath (8909, 16)
# 31_existence_omnipath (8909, 16)
# 79_existence_omnipath (8909, 16)
# 225_existence_omnipath (8909, 16)
# 206_existence_omnipath (8909, 16)
# 143_existence_omnipath (8909, 16)
# 40_existence_omnipath (8909, 16)
# 123_existence_omnipath (8909, 16)
# 28_existence_omnipath (8909, 16)
# 197_existence_omnipath (8909, 16)
# 154_existence_omnipath (8909, 16)
# 139_existence_omnipath (8909, 16)
# 165_existence_omnipath (8909, 16)
# 167_existence_omnipath (8909, 16)
# 148_existence_omnipath (8909, 16)
# 218_existence_omnipath (8909, 16)
# 164_existence_omnipath (8909, 16)
# 83_existence_omnipath (8909, 16)
# 169_existence_omnipath (8909, 16)
# 184_existence_omnipath (8909, 16)
# 142_existence_omnipath (8909, 16)
# 1_existence_omnipath (8909, 16)
# 58_existence_omnipath (8909, 16)
# 122_existence_omnipath (8909, 16)
# 249_existence_omnipath (8909, 16)
# 106_existence_omnipath (8909, 16)
# 38_existence_omnipath (8909, 16)
# 96_existence_omnipath (8909, 16)
# 241_existence_omnipath (8909, 16)
# 92_existence_omnipath (8909, 16)
# 111_existence_omnipath (8909, 16)
# 240_existence_omnipath (8909, 16)
# 138_existence_omnipath (8909, 16)
# 6_existence_omnipath (8909, 16)
# 5_existence_omnipath (8909, 16)
# 137_existence_omnipath (8909, 16)
# 170_existence_omnipath (8909, 16)
# 158_existence_omnipath (8909, 16)
# 131_existence_omnipath (8909, 16)
# 60_existence_omnipath (8909, 16)
# 124_existence_omnipath (8909, 16)
# 257_existence_omnipath (8909, 16)
# 281_existence_omnipath (8909, 16)
# 153_existence_omnipath (8909, 16)
# 248_existence_omnipath (8909, 16)
# 113_existence_omnipath (8909, 16)
# 231_existence_omnipath (8909, 16)
# 200_existence_omnipath (8909, 16)
# 279_existence_omnipath (8909, 16)
# 251_existence_omnipath (8909, 16)
# 166_existence_omnipath (8909, 16)
# 222_existence_omnipath (8909, 16)
# 41_existence_omnipath (8909, 16)
# 125_existence_omnipath (8909, 16)
# 156_existence_omnipath (8909, 16)
# 101_existence_omnipath (8909, 16)
# 55_existence_omnipath (8909, 16)
# 22_existence_omnipath (8909, 16)
# 91_existence_omnipath (8909, 16)
# 255_existence_omnipath (8909, 16)
# 44_existence_omnipath (8909, 16)
# 182_existence_omnipath (8909, 16)
# 63_existence_omnipath (8909, 16)
# 259_existence_omnipath (8909, 16)
# 203_existence_omnipath (8909, 16)
# 26_existence_omnipath (8909, 16)
# 70_existence_omnipath (8909, 16)
# 36_existence_omnipath (8909, 16)
# 109_existence_omnipath (8909, 16)
# 172_existence_omnipath (8909, 16)
# 114_existence_omnipath (8909, 16)
# 239_existence_omnipath (8909, 16)
# 155_existence_omnipath (8909, 16)
# 34_existence_omnipath (8909, 16)
# 102_existence_omnipath (8909, 16)
# 168_existence_omnipath (8909, 16)
# 67_existence_omnipath (8909, 16)
# 134_existence_omnipath (8909, 16)
# 235_existence_omnipath (8909, 16)
# 98_existence_omnipath (8909, 16)
# 152_existence_omnipath (8909, 16)
# 12_existence_omnipath (8909, 16)
# 18_existence_omnipath (8909, 16)
# 174_existence_omnipath (8909, 16)
# 246_existence_omnipath (8909, 16)
# 202_existence_omnipath (8909, 16)
# 8_existence_omnipath (8909, 16)
# 85_existence_omnipath (8909, 16)
# 52_existence_omnipath (8909, 16)
# 278_existence_omnipath (8909, 16)
# 190_existence_omnipath (8909, 16)
# 275_existence_omnipath (8909, 16)
# 221_existence_omnipath (8909, 16)
# 32_existence_omnipath (8909, 16)
# 119_existence_omnipath (8909, 16)
# 149_existence_omnipath (8909, 16)
# 126_existence_omnipath (8909, 16)
# 61_existence_omnipath (8909, 16)
# 192_existence_omnipath (8909, 16)
# 191_existence_omnipath (8909, 16)
# 87_existence_omnipath (8909, 16)
# 49_existence_omnipath (8909, 16)
# 25_existence_omnipath (8909, 16)
# 210_existence_omnipath (8909, 16)
# 77_existence_omnipath (8909, 16)
# 128_existence_omnipath (8909, 16)
# 81_existence_omnipath (8909, 16)
# 73_existence_omnipath (8909, 16)
# 228_existence_omnipath (8909, 16)
# 37_existence_omnipath (8909, 16)
# 118_existence_omnipath (8909, 16)
# 75_existence_omnipath (8909, 16)
# 233_existence_omnipath (8909, 16)
# 95_existence_omnipath (8909, 16)
# 195_existence_omnipath (8909, 16)
# 273_existence_omnipath (8909, 16)
# 56_existence_omnipath (8909, 16)
# 45_existence_omnipath (8909, 16)
# 176_existence_omnipath (8909, 16)
# 30_existence_omnipath (8909, 16)
# 242_existence_omnipath (8909, 16)
# 183_existence_omnipath (8909, 16)
# 244_existence_omnipath (8909, 16)
# 120_existence_omnipath (8909, 16)
# 117_existence_omnipath (8909, 16)
# 264_existence_omnipath (8909, 16)
# 24_existence_omnipath (8909, 16)
# 217_existence_omnipath (8909, 16)
# 263_existence_omnipath (8909, 16)
# 280_existence_omnipath (8909, 16)
# 212_existence_omnipath (8909, 16)
# 42_existence_omnipath (8909, 16)
# 161_existence_omnipath (8909, 16)
# 245_existence_omnipath (8909, 16)
# 62_existence_omnipath (8909, 16)
# 175_existence_omnipath (8909, 16)
# 112_existence_omnipath (8909, 16)
# 133_existence_omnipath (8909, 16)
# 130_existence_omnipath (8909, 16)
# 185_existence_omnipath (8909, 16)
# 0_existence_omnipath (8909, 16)
# 14_existence_omnipath (8909, 16)
# 268_existence_omnipath (8909, 16)
# 201_existence_omnipath (8909, 16)
# 107_existence_omnipath (8909, 16)
# 69_existence_omnipath (8909, 16)
# 145_existence_omnipath (8909, 16)
# 237_existence_omnipath (8909, 16)
# 189_existence_omnipath (8909, 16)
# 99_existence_omnipath (8909, 16)
# 256_existence_omnipath (8909, 16)
# 236_existence_omnipath (8909, 16)
# 209_existence_omnipath (8909, 16)
# 173_existence_omnipath (8909, 16)
# 254_existence_omnipath (8909, 16)
# 15_existence_omnipath (8909, 16)
# 163_existence_omnipath (8909, 16)
# 47_existence_omnipath (8909, 16)
# 78_existence_omnipath (8909, 16)
# 135_existence_omnipath (8909, 16)
# 261_existence_omnipath (8909, 16)
# 146_existence_omnipath (8909, 16)
# 188_existence_omnipath (8909, 16)
# 198_existence_omnipath (8909, 16)
# 51_existence_omnipath (8909, 16)
# 215_existence_omnipath (8909, 16)
# 74_existence_omnipath (8909, 16)
# 286_existence_omnipath (8909, 16)
# 103_existence_omnipath (8909, 16)
# 253_existence_omnipath (8909, 16)
# 177_existence_omnipath (8909, 16)
# 27_existence_omnipath (8909, 16)
# 54_existence_omnipath (8909, 16)
# 186_existence_omnipath (8909, 16)
# 199_existence_omnipath (8909, 16)
# 157_existence_omnipath (8909, 16)
# 151_existence_omnipath (8909, 16)
# 159_existence_omnipath (8909, 16)
# 178_existence_omnipath (8909, 16)
# 260_existence_omnipath (8909, 16)
# 97_existence_omnipath (8909, 16)

# %% [markdown]
# ## Random Link Split

# %%
transform = T.RandomLinkSplit(num_val=0.05, num_test=0.1, is_undirected=False, add_negative_train_samples=True, )
train, val, test = transform(data, )

# %%
aurocs_val = {}
aurocs_test = {}

# %%
for method, embedding in {**embeddings}.items():
    X_train = np.hstack((embedding[train.edge_label_index[0]], embedding[train.edge_label_index[1]]))
    y_train = train.edge_label.detach().cpu().numpy()

    X_val = np.hstack((embedding[val.edge_label_index[0]], embedding[val.edge_label_index[1]]))
    y_val = val.edge_label.detach().cpu().numpy()
    
    X_test = np.hstack((embedding[test.edge_label_index[0]], embedding[test.edge_label_index[1]]))
    y_test = test.edge_label.detach().cpu().numpy()
    
    clf = linear_model.RidgeClassifier(random_state=42)
    clf.fit(X_train, y_train)
    
    y_score_val = clf.decision_function(X_val)
    y_score_test = clf.decision_function(X_test)

    aurocs_val[method] = metrics.roc_auc_score(y_val, y_score_val)
    aurocs_test[method] = metrics.roc_auc_score(y_test, y_score_test)

# %%
aurocs_val = dict(sorted(aurocs_val.items(), key=lambda item: item[1], reverse=False) )
best_run = list(aurocs_val.keys())[-1]

# %%
print(best_run, aurocs_test[best_run])
# Out:
# 78_existence_omnipath 0.9489938603696803

# %% [markdown]
# ## Link Split based on Directedness of Edge

# %% [markdown]
# ## First split all positive edges

# %%
transform = T.RandomLinkSplit(num_val=0.05, num_test=0.1, is_undirected=False, add_negative_train_samples=False, )
train, val, test = transform(data, )

# %%
aurocs_val = {}
aurocs_test = {}

# %%
A = nx.adj_matrix(G).todense()
# Out:
# <ipython-input-47-e7c8b4052a2f>:1: DeprecationWarning: adj_matrix is deprecated and will be removed in version 3.0.
# Use `adjacency_matrix` instead
#
#   A = nx.adj_matrix(G).todense()

# %%
train_id_neg_edges = np.where(A[train.edge_label_index[1], train.edge_label_index[0]] == 0)[1]
val_id_neg_edges = np.where(A[val.edge_label_index[1], val.edge_label_index[0]] == 0)[1]

# %%
for method, embedding in {**embeddings}.items():
        
    X_train_pos = np.hstack((embedding[train.edge_label_index[0]], embedding[train.edge_label_index[1]]))
    X_train_neg = np.hstack((embedding[train.edge_label_index[1][train_id_neg_edges]], embedding[train.edge_label_index[0][train_id_neg_edges]]))
    X_train = np.vstack((X_train_pos, X_train_neg))
    y_train = [1]*(X_train_pos.shape[0]) + [0]*(X_train_neg.shape[0])

    X_val_pos = np.hstack((embedding[val.edge_label_index[0]], embedding[val.edge_label_index[1]]))
    X_val_neg = np.hstack((embedding[val.edge_label_index[1][val_id_neg_edges]], embedding[val.edge_label_index[0][val_id_neg_edges]]))
    X_val = np.vstack((X_val_pos, X_val_neg))
    y_val = [1]*(X_val_pos.shape[0]) + [0]*(X_val_neg.shape[0])
    
    X_test_pos = np.hstack((embedding[test.edge_label_index[0]], embedding[test.edge_label_index[1]]))
    X_test_neg = np.hstack((embedding[test.edge_label_index[1]], embedding[test.edge_label_index[0]]))
    X_test = np.vstack((X_test_pos, X_test_neg))
    y_test = [1]*(X_test.shape[0]//2) + [0]*(X_test.shape[0]//2)
    
    clf = linear_model.RidgeClassifier(random_state=42)
    clf.fit(X_train, y_train)
    
    y_score_val = clf.decision_function(X_val)
    y_score_test = clf.decision_function(X_test)
    
    aurocs_val[method] = metrics.roc_auc_score(y_val, y_score_val)
    aurocs_test[method] = metrics.roc_auc_score(y_test, y_score_test)

# %%
aurocs_val = dict(sorted(aurocs_val.items(), key=lambda item: item[1], reverse=False) )
best_run = list(aurocs_val.keys())[-1]

# %%
print(best_run, aurocs_test[best_run])
# Out:
# 46_existence_omnipath 0.7125151182658793
